# %%
from datasets import load_dataset

dataset = load_dataset("dair-ai/emotion")
dataset
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset emotion downloaded and prepared to /root/.cache/huggingface/datasets/dair-ai___emotion/split/1.0.0/cca5efe2dfeb58c1d098e0f9eeb200e9927d889b5a03c67097275dfb5fe463bd. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.DataFrame(dataset['train'])
validation_df = pd.DataFrame(dataset['validation'])
test_df = pd.DataFrame(dataset['test'])

# %%
print("train_df shape: " ,train_df.shape)
print("validation_df shape: " ,validation_df.shape)
print("test_df shape: " ,test_df.shape)
# Out:
# train_df shape:  (16000, 2)
# validation_df shape:  (2000, 2)
# test_df shape:  (2000, 2)

# %%
validation_df.head()
# Out:
#                                                 text  label
# 0  im feeling quite sad and sorry for myself but ...      0
# 1  i feel like i am still looking at a blank canv...      0
# 2                     i feel like a faithful servant      2
# 3                  i am just feeling cranky and blue      3
# 4  i can have for a treat or if i am feeling festive      1

# %%
test_df.head()
# Out:
#                                                 text  label
# 0  im feeling rather rotten so im not very ambiti...      0
# 1          im updating my blog because i feel shitty      0
# 2  i never make her separate from me because i do...      0
# 3  i left with my bouquet of red and yellow tulip...      1
# 4    i was feeling a little vain when i did this one      0

# %%
train_df.head()
# Out:
#                                                 text  label
# 0                            i didnt feel humiliated      0
# 1  i can go from feeling so hopeless to so damned...      0
# 2   im grabbing a minute to post i feel greedy wrong      3
# 3  i am ever feeling nostalgic about the fireplac...      2
# 4                               i am feeling grouchy      3

# %%
X_train=train_df['text']
y_train = train_df['label']
X_test = train_df['text']
y_test=train_df['label']

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

model = Pipeline(steps=[('cv', CountVectorizer()), ('rf', RandomForestClassifier())])
# Train and evaluate model
model.fit(X_train, y_train)
y_preds = model.predict(X_test)
acc_score = accuracy_score(y_test, y_preds)
print("Accuracy: ",acc_score)
# Out:
# Accuracy:  0.998125

# %%
# Mapping of integer labels to emotions
label_to_emotion = {
    0: "sadness",
    1: "joy",
    2: "love",
    3: "anger",
    4: "fear",
    5: "surprise"
}

# %%
text = validation_df['text'][50]

# %%
predicted_label = model.predict([text])

# Get the corresponding emotion label
predicted_emotion = label_to_emotion[predicted_label[0]]  # Assuming it's a single prediction

# Print the predicted emotion
print("Predicted Emotion:", predicted_emotion)
# Out:
# Predicted Emotion: sadness

# %%
import joblib

# %%
model_file = open('Emotion_detection_model.pkl','wb')
joblib.dump(model,model_file)

# %%
# !cd /kaggle/working

# %%
# !ls
# Out:
# Emotion_detection_model.pkl  __notebook__.ipynb

# %%
from IPython.display import FileLink
# !zip -r model_file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/Emotion_detection_model.pkl (deflated 88%)
#   adding: kaggle/working/__notebook__.ipynb (deflated 84%)

# %%
from IPython.display import FileLink
FileLink(r'model_file.zip')
# Out:
# /kaggle/working/model_file.zip
